# %% [markdown]
# <a href="https://colab.research.google.com/github/qasim-mansoor/Time-Series-Analysis-with-Arima/blob/main/Time_Series_Forecasting_with_Arima.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pmdarima
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 8.9 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/data/MaunaLoaDailyTemps.csv',index_col='DATE', parse_dates=True)

# %%
df
# Out:
#             MinTemp  MaxTemp  AvgTemp  Sunrise  Sunset
# DATE
# 2014-01-01     33.0     46.0     40.0      657    1756
# 2014-01-02     35.0     50.0     43.0      657    1756
# 2014-01-03     36.0     45.0     41.0      657    1757
# 2014-01-04     32.0     41.0     37.0      658    1757
# 2014-01-05     24.0     38.0     31.0      658    1758
# ...             ...      ...      ...      ...     ...
# 2018-12-26     35.0     45.0     40.0      654    1752
# 2018-12-27     33.0     44.0     39.0      655    1752
# 2018-12-28     33.0     47.0     40.0      655    1753
# 2018-12-29     36.0     47.0     42.0      655    1753
# 2018-12-30     39.0     52.0     46.0      656    1754
#
# [1825 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# MinTemp    4
# MaxTemp    4
# AvgTemp    4
# Sunrise    0
# Sunset     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (1821, 5)

# %%
df.head()
# Out:
#             MinTemp  MaxTemp  AvgTemp  Sunrise  Sunset
# DATE
# 2014-01-01     33.0     46.0     40.0      657    1756
# 2014-01-02     35.0     50.0     43.0      657    1756
# 2014-01-03     36.0     45.0     41.0      657    1757
# 2014-01-04     32.0     41.0     37.0      658    1757
# 2014-01-05     24.0     38.0     31.0      658    1758

# %%
df["AvgTemp"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
from statsmodels.tsa.stattools import adfuller
def ad_test(dataset):
     dftest = adfuller(dataset, autolag = 'AIC')
     print("1. ADF : ",dftest[0])
     print("2. P-Value : ", dftest[1])
     print("3. Num Of Lags : ", dftest[2])
     print("4. Num Of Observations Used For ADF Regression:",      dftest[3])
     print("5. Critical Values :")
     for key, val in dftest[4].items():
         print("\t",key, ": ", val)

ad_test(df['AvgTemp'])
# Out:
# 1. ADF :  -6.554680125068777
# 2. P-Value :  8.675937480199653e-09
# 3. Num Of Lags :  12
# 4. Num Of Observations Used For ADF Regression: 1808
# 5. Critical Values :
# 	 1% :  -3.433972018026501
# 	 5% :  -2.8631399192826676
# 	 10% :  -2.5676217442756872

# %%
from pmdarima import auto_arima
stepwise_fit = auto_arima(df['AvgTemp'], trace=True,
suppress_warnings=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=8344.735, Time=4.85 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=10347.755, Time=0.12 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=8365.701, Time=0.59 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=9136.225, Time=0.67 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=19192.139, Time=0.09 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=8355.947, Time=8.29 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=8356.308, Time=6.28 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=8347.311, Time=5.78 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=8318.337, Time=6.00 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=8330.192, Time=8.26 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=8310.577, Time=7.81 sec
#  ARIMA(4,0,3)(0,0,0)[0] intercept   : AIC=8332.293, Time=6.72 sec
#  ARIMA(3,0,4)(0,0,0)[0] intercept   : AIC=8317.620, Time=6.05 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=8306.228, Time=7.19 sec
# ...

# %%
print(df.shape)
train=df.iloc[:-30]
test=df.iloc[-30:]
print(train.shape,test.shape)
# Out:
# (1821, 5)
# (1791, 5) (30, 5)

# %%
from statsmodels.tsa.arima.model import ARIMA
model=ARIMA(train['AvgTemp'],order=(1,0,5))
model=model.fit()
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                AvgTemp   No. Observations:                 1791
# ...

# %%
start=len(train)
end=len(train)+len(test)-1
pred=model.predict(start=start,end=end,typ='levels').rename('ARIMA Predictions')
pred.plot(legend=True)
test['AvgTemp'].plot(legend=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['type']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)
# <Axes: xlabel='DATE'>

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
test['AvgTemp'].mean()
rmse=sqrt(mean_squared_error(pred,test['AvgTemp']))
print(rmse)
# Out:
# 3.000463825206671
